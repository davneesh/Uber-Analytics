# %% [markdown]
# <a href="https://colab.research.google.com/github/davneesh/Uber-Analytics/blob/main/Uber_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
uber = pd.read_csv('/content/drive/MyDrive/Projects/Uber Analytics/uber_data.csv')

# %%
uber
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1             1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2             2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3             2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4             2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
# ...         ...                  ...                   ...              ...
# 19853         2  2016-03-10 08:51:45   2016-03-10 09:05:48                1
# 19854         2  2016-03-10 08:51:45   2016-03-10 08:59:43                5
# 19855         2  2016-03-10 08:51:45   2016-03-10 08:56:58                5
# 19856         2  2016-03-10 08:51:45   2016-03-10 09:07:37                1
# 19857         2  2016-03-10 08:51:46   2016-03-10 08:57:01                2
#
#        trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0               2.50        -73.976746        40.765152           1
# 1               2.90        -73.983482        40.767925           1
# 2              19.98        -73.782021        40.644810           1
# 3              10.78        -73.863419        40.769814           1
# 4              30.43        -73.971741        40.792183           3
# ...              ...               ...              ...         ...
# 19853           2.26        -73.983467        40.750038           1
# 19854           1.18        -73.983513        40.756008           1
# 19855           1.36        -73.968224        40.768002           1
# 19856           1.49        -73.972488        40.749393           1
# 19857           0.65        -73.951469        40.782261           1
#
#       store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                      N         -74.004265         40.746128           1.0
# 1                      N         -74.005943         40.733166           1.0
# 2                      N         -73.974541         40.675770           1.0
# 3                      N         -73.969650         40.757767           1.0
# 4                      N         -74.177170         40.695053           1.0
# ...                  ...                ...               ...           ...
# 19853                  N         -74.008774         40.730461           1.0
# 19854                  N         -73.967613         40.757580           1.0
# 19855                  N         -73.955742         40.785141           1.0
# 19856                  N         -73.989326         40.740543           1.0
# 19857                  N         -73.953293         40.788300           NaN
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              9.0    0.5      0.5        2.05          0.00
# 1             11.0    0.5      0.5        3.05          0.00
# 2             54.5    0.5      0.5        8.00          0.00
# 3             31.5    0.0      0.5        3.78          5.54
# 4             98.0    0.0      0.0        0.00         15.50
# ...            ...    ...      ...         ...           ...
# 19853         11.0    0.0      0.5        2.36          0.00
# 19854          7.0    0.0      0.5        1.20          0.00
# 19855          6.5    0.0      0.5        1.46          0.00
# 19856         11.5    0.0      0.5        1.00          0.00
# 19857          NaN    NaN      NaN         NaN           NaN
#
#        improvement_surcharge  total_amount
# 0                        0.3         12.35
# 1                        0.3         15.35
# 2                        0.3         63.80
# 3                        0.3         41.62
# 4                        0.3        113.80
# ...                      ...           ...
# 19853                    0.3         14.16
# 19854                    0.3          9.00
# 19855                    0.3          8.76
# 19856                    0.3         13.30
# 19857                    NaN           NaN
#
# [19858 rows x 19 columns]

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19858 entries, 0 to 19857
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               19858 non-null  int64
#  1   tpep_pickup_datetime   19858 non-null  object
#  2   tpep_dropoff_datetime  19858 non-null  object
#  3   passenger_count        19858 non-null  int64
#  4   trip_distance          19858 non-null  float64
#  5   pickup_longitude       19858 non-null  float64
#  6   pickup_latitude        19858 non-null  float64
#  7   RatecodeID             19858 non-null  int64
#  8   store_and_fwd_flag     19858 non-null  object
#  9   dropoff_longitude      19858 non-null  float64
#  10  dropoff_latitude       19858 non-null  float64
#  11  payment_type           19857 non-null  float64
#  12  fare_amount            19857 non-null  float64
#  13  extra                  19857 non-null  float64
#  14  mta_tax                19857 non-null  float64
#  15  tip_amount             19857 non-null  float64
#  16  tolls_amount           19857 non-null  float64
#  17  improvement_surcharge  19857 non-null  float64
#  18  total_amount           19857 non-null  float64
# dtypes: float64(13), int64(3), object(3)
# memory usage: 2.9+ MB

# %%
uber.describe()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  19858.000000     19858.000000   19858.000000      19858.000000
# mean       1.996576         2.015409       2.690797        -73.399266
# std        0.058419         1.653302       3.285490          6.489204
# min        1.000000         0.000000       0.000000        -74.651306
# 25%        2.000000         1.000000       1.010000        -73.990608
# 50%        2.000000         1.000000       1.640000        -73.978355
# 75%        2.000000         2.000000       2.810000        -73.961229
# max        2.000000         6.000000      45.680000          0.000000
#
#        pickup_latitude    RatecodeID  dropoff_longitude  dropoff_latitude  \
# count     19858.000000  19858.000000       19858.000000      19858.000000
# mean         40.439352      1.029812         -73.419553         40.448104
# std           3.575286      0.237319           6.383961          3.517087
# min           0.000000      1.000000         -74.651306          0.000000
# 25%          40.741532      1.000000         -73.989485         40.741779
# 50%          40.756851      1.000000         -73.978096         40.756306
# 75%          40.773079      1.000000         -73.967331         40.766665
# max          40.903011      5.000000           0.000000         41.031750
#
#        payment_type   fare_amount         extra       mta_tax    tip_amount  \
# count  19857.000000  19857.000000  19857.000000  19857.000000  19857.000000
# mean       1.265146     12.189461      0.004356      0.497507      1.854832
# std        0.444378     10.169387      0.055596      0.039274      2.331182
# min        1.000000     -7.500000      0.000000     -0.500000     -2.340000
# 25%        1.000000      6.500000      0.000000      0.500000      0.000000
# 50%        1.000000      9.000000      0.000000      0.500000      1.460000
# 75%        2.000000     13.500000      0.000000      0.500000      2.360000
# max        4.000000    225.000000      4.500000      0.500000     47.560000
#
#        tolls_amount  improvement_surcharge  total_amount
# count  19857.000000           19857.000000  19857.000000
# mean       0.283753               0.299411     15.129320
# std        1.363758               0.016888     12.841546
# min        0.000000              -0.300000    -10.140000
# 25%        0.000000               0.300000      8.300000
# 50%        0.000000               0.300000     11.300000
# 75%        0.000000               0.300000     16.560000
# max       24.500000               0.300000    285.360000

# %%
uber.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1         1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2         2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3         2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4         2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           2.50        -73.976746        40.765152           1
# 1           2.90        -73.983482        40.767925           1
# 2          19.98        -73.782021        40.644810           1
# 3          10.78        -73.863419        40.769814           1
# 4          30.43        -73.971741        40.792183           3
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -74.004265         40.746128           1.0
# 1                  N         -74.005943         40.733166           1.0
# 2                  N         -73.974541         40.675770           1.0
# 3                  N         -73.969650         40.757767           1.0
# 4                  N         -74.177170         40.695053           1.0
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          9.0    0.5      0.5        2.05          0.00
# 1         11.0    0.5      0.5        3.05          0.00
# 2         54.5    0.5      0.5        8.00          0.00
# 3         31.5    0.0      0.5        3.78          5.54
# 4         98.0    0.0      0.0        0.00         15.50
#
#    improvement_surcharge  total_amount
# 0                    0.3         12.35
# 1                    0.3         15.35
# 2                    0.3         63.80
# 3                    0.3         41.62
# 4                    0.3        113.80

# %%
uber['tpep_pickup_datetime'] = pd.to_datetime(uber['tpep_pickup_datetime'])
uber['tpep_dropoff_datetime'] = pd.to_datetime(uber['tpep_dropoff_datetime'])

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19858 entries, 0 to 19857
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               19858 non-null  int64
#  1   tpep_pickup_datetime   19858 non-null  datetime64[ns]
#  2   tpep_dropoff_datetime  19858 non-null  datetime64[ns]
#  3   passenger_count        19858 non-null  int64
#  4   trip_distance          19858 non-null  float64
#  5   pickup_longitude       19858 non-null  float64
#  6   pickup_latitude        19858 non-null  float64
#  7   RatecodeID             19858 non-null  int64
#  8   store_and_fwd_flag     19858 non-null  object
#  9   dropoff_longitude      19858 non-null  float64
#  10  dropoff_latitude       19858 non-null  float64
#  11  payment_type           19857 non-null  float64
#  12  fare_amount            19857 non-null  float64
#  13  extra                  19857 non-null  float64
#  14  mta_tax                19857 non-null  float64
#  15  tip_amount             19857 non-null  float64
#  16  tolls_amount           19857 non-null  float64
#  17  improvement_surcharge  19857 non-null  float64
#  18  total_amount           19857 non-null  float64
# dtypes: datetime64[ns](2), float64(13), int64(3), object(1)
# memory usage: 2.9+ MB

# %%
datetime_dim = uber[['tpep_pickup_datetime','tpep_dropoff_datetime']].drop_duplicates().reset_index(drop=True)
datetime_dim['pick_hour'] = datetime_dim['tpep_pickup_datetime'].dt.hour
datetime_dim['pick_day'] = datetime_dim['tpep_pickup_datetime'].dt.day
datetime_dim['pick_month'] = datetime_dim['tpep_pickup_datetime'].dt.month
datetime_dim['pick_year'] = datetime_dim['tpep_pickup_datetime'].dt.year
datetime_dim['pick_weekday'] = datetime_dim['tpep_pickup_datetime'].dt.weekday
datetime_dim['drop_hour'] = datetime_dim['tpep_dropoff_datetime'].dt.hour
datetime_dim['drop_day'] = datetime_dim['tpep_dropoff_datetime'].dt.day
datetime_dim['drop_month'] = datetime_dim['tpep_dropoff_datetime'].dt.month
datetime_dim['drop_year'] = datetime_dim['tpep_dropoff_datetime'].dt.year
datetime_dim['drop_weekday'] =datetime_dim['tpep_dropoff_datetime'].dt.weekday

# %%
datetime_dim
# Out:
#       tpep_pickup_datetime tpep_dropoff_datetime  pick_hour  pick_day  \
# 0      2016-03-01 00:00:00   2016-03-01 00:07:55          0         1
# 1      2016-03-01 00:00:00   2016-03-01 00:11:06          0         1
# 2      2016-03-01 00:00:00   2016-03-01 00:31:06          0         1
# 3      2016-03-01 00:00:00   2016-03-01 00:00:00          0         1
# 4      2016-03-01 00:00:01   2016-03-01 00:16:04          0         1
# ...                    ...                   ...        ...       ...
# 19818  2016-03-10 08:51:45   2016-03-10 09:05:48          8        10
# 19819  2016-03-10 08:51:45   2016-03-10 08:59:43          8        10
# 19820  2016-03-10 08:51:45   2016-03-10 08:56:58          8        10
# 19821  2016-03-10 08:51:45   2016-03-10 09:07:37          8        10
# 19822  2016-03-10 08:51:46   2016-03-10 08:57:01          8        10
#
#        pick_month  pick_year  pick_weekday  drop_hour  drop_day  drop_month  \
# 0               3       2016             1          0         1           3
# 1               3       2016             1          0         1           3
# 2               3       2016             1          0         1           3
# 3               3       2016             1          0         1           3
# 4               3       2016             1          0         1           3
# ...           ...        ...           ...        ...       ...         ...
# 19818           3       2016             3          9        10           3
# 19819           3       2016             3          8        10           3
# 19820           3       2016             3          8        10           3
# 19821           3       2016             3          9        10           3
# 19822           3       2016             3          8        10           3
#
#        drop_year  drop_weekday
# 0           2016             1
# 1           2016             1
# 2           2016             1
# 3           2016             1
# 4           2016             1
# ...          ...           ...
# 19818       2016             3
# 19819       2016             3
# 19820       2016             3
# 19821       2016             3
# 19822       2016             3
#
# [19823 rows x 12 columns]

# %%
datetime_dim['datetime_id'] = datetime_dim.index

# %%
datetime_dim
# Out:
#       tpep_pickup_datetime tpep_dropoff_datetime  pick_hour  pick_day  \
# 0      2016-03-01 00:00:00   2016-03-01 00:07:55          0         1
# 1      2016-03-01 00:00:00   2016-03-01 00:11:06          0         1
# 2      2016-03-01 00:00:00   2016-03-01 00:31:06          0         1
# 3      2016-03-01 00:00:00   2016-03-01 00:00:00          0         1
# 4      2016-03-01 00:00:01   2016-03-01 00:16:04          0         1
# ...                    ...                   ...        ...       ...
# 19818  2016-03-10 08:51:45   2016-03-10 09:05:48          8        10
# 19819  2016-03-10 08:51:45   2016-03-10 08:59:43          8        10
# 19820  2016-03-10 08:51:45   2016-03-10 08:56:58          8        10
# 19821  2016-03-10 08:51:45   2016-03-10 09:07:37          8        10
# 19822  2016-03-10 08:51:46   2016-03-10 08:57:01          8        10
#
#        pick_month  pick_year  pick_weekday  drop_hour  drop_day  drop_month  \
# 0               3       2016             1          0         1           3
# 1               3       2016             1          0         1           3
# 2               3       2016             1          0         1           3
# 3               3       2016             1          0         1           3
# 4               3       2016             1          0         1           3
# ...           ...        ...           ...        ...       ...         ...
# 19818           3       2016             3          9        10           3
# 19819           3       2016             3          8        10           3
# 19820           3       2016             3          8        10           3
# 19821           3       2016             3          9        10           3
# 19822           3       2016             3          8        10           3
#
#        drop_year  drop_weekday  datetime_id
# 0           2016             1            0
# 1           2016             1            1
# 2           2016             1            2
# 3           2016             1            3
# 4           2016             1            4
# ...          ...           ...          ...
# 19818       2016             3        19818
# 19819       2016             3        19819
# 19820       2016             3        19820
# 19821       2016             3        19821
# 19822       2016             3        19822
#
# [19823 rows x 13 columns]

# %%
datetime_dim = datetime_dim[['datetime_id','tpep_pickup_datetime','pick_hour',	'pick_day',	'pick_month',	'pick_year',	'pick_weekday', 'tpep_dropoff_datetime','drop_hour',	'drop_day',	'drop_month',	'drop_year',	'drop_weekday']]

# %%
datetime_dim
# Out:
#        datetime_id tpep_pickup_datetime  pick_hour  pick_day  pick_month  \
# 0                0  2016-03-01 00:00:00          0         1           3
# 1                1  2016-03-01 00:00:00          0         1           3
# 2                2  2016-03-01 00:00:00          0         1           3
# 3                3  2016-03-01 00:00:00          0         1           3
# 4                4  2016-03-01 00:00:01          0         1           3
# ...            ...                  ...        ...       ...         ...
# 19818        19818  2016-03-10 08:51:45          8        10           3
# 19819        19819  2016-03-10 08:51:45          8        10           3
# 19820        19820  2016-03-10 08:51:45          8        10           3
# 19821        19821  2016-03-10 08:51:45          8        10           3
# 19822        19822  2016-03-10 08:51:46          8        10           3
#
#        pick_year  pick_weekday tpep_dropoff_datetime  drop_hour  drop_day  \
# 0           2016             1   2016-03-01 00:07:55          0         1
# 1           2016             1   2016-03-01 00:11:06          0         1
# 2           2016             1   2016-03-01 00:31:06          0         1
# 3           2016             1   2016-03-01 00:00:00          0         1
# 4           2016             1   2016-03-01 00:16:04          0         1
# ...          ...           ...                   ...        ...       ...
# 19818       2016             3   2016-03-10 09:05:48          9        10
# 19819       2016             3   2016-03-10 08:59:43          8        10
# 19820       2016             3   2016-03-10 08:56:58          8        10
# 19821       2016             3   2016-03-10 09:07:37          9        10
# 19822       2016             3   2016-03-10 08:57:01          8        10
#
#        drop_month  drop_year  drop_weekday
# 0               3       2016             1
# 1               3       2016             1
# 2               3       2016             1
# 3               3       2016             1
# 4               3       2016             1
# ...           ...        ...           ...
# 19818           3       2016             3
# 19819           3       2016             3
# 19820           3       2016             3
# 19821           3       2016             3
# 19822           3       2016             3
#
# [19823 rows x 13 columns]

# %%
pasanger_count_dim = uber[['passenger_count']].drop_duplicates().reset_index(drop=True)
pasanger_count_dim['passenger_count_id'] = pasanger_count_dim.index
pasanger_count_dim = pasanger_count_dim[['passenger_count_id','passenger_count']]

# %%
pasanger_count_dim
# Out:
#    passenger_count_id  passenger_count
# 0                   0                1
# 1                   1                2
# 2                   2                3
# 3                   3                5
# 4                   4                6
# 5                   5                4
# 6                   6                0

# %%
trip_distance_dim = uber[['trip_distance']].drop_duplicates().reset_index(drop=True)
trip_distance_dim['trip_distance_id'] = trip_distance_dim.index
trip_distance_dim = trip_distance_dim[['trip_distance_id','trip_distance']]

# %%
trip_distance_dim
# Out:
#       trip_distance_id  trip_distance
# 0                    0           2.50
# 1                    1           2.90
# 2                    2          19.98
# 3                    3          10.78
# 4                    4          30.43
# ...                ...            ...
# 1537              1537          21.25
# 1538              1538          14.11
# 1539              1539           0.12
# 1540              1540           8.24
# 1541              1541          12.31
#
# [1542 rows x 2 columns]

# %%
rate_code_dim = uber[['RatecodeID']].drop_duplicates().reset_index(drop=True)
rate_code_dim['rate_code_id'] = rate_code_dim.index
rate_code_dim = rate_code_dim[['rate_code_id','RatecodeID']]

# %%
rate_code_dim
# Out:
#    rate_code_id  RatecodeID
# 0             0           1
# 1             1           3
# 2             2           2
# 3             3           5
# 4             4           4

# %%
rate_code_type = {
    1 : "Standard rate",
    2 : "JFK",
    3 : "Newark",
    4 : "Nassau or Westchester",
    5 : "Negotiated fare",
    6 : "Group ride"
}
rate_code_dim['rate_code_name'] = rate_code_dim['RatecodeID'].map(rate_code_type)

# %%
rate_code_dim
# Out:
#    rate_code_id  RatecodeID         rate_code_name
# 0             0           1          Standard rate
# 1             1           3                 Newark
# 2             2           2                    JFK
# 3             3           5        Negotiated fare
# 4             4           4  Nassau or Westchester

# %%
pickup_location_dim = uber[['pickup_longitude','pickup_latitude']].drop_duplicates().reset_index(drop=True)
pickup_location_dim['pickup_location_id'] = pickup_location_dim.index
pickup_location_dim = pickup_location_dim[['pickup_location_id','pickup_latitude','pickup_longitude']]

# %%
pickup_location_dim
# Out:
#        pickup_location_id  pickup_latitude  pickup_longitude
# 0                       0        40.765152        -73.976746
# 1                       1        40.767925        -73.983482
# 2                       2        40.644810        -73.782021
# 3                       3        40.769814        -73.863419
# 4                       4        40.792183        -73.971741
# ...                   ...              ...               ...
# 19589               19589        40.750038        -73.983467
# 19590               19590        40.756008        -73.983513
# 19591               19591        40.768002        -73.968224
# 19592               19592        40.749393        -73.972488
# 19593               19593        40.782261        -73.951469
#
# [19594 rows x 3 columns]

# %%
dropoff_location_dim = uber[['dropoff_longitude','dropoff_latitude']].drop_duplicates().reset_index(drop=True)
dropoff_location_dim['dropoff_location_id'] = dropoff_location_dim.index
dropoff_location_dim = dropoff_location_dim[['dropoff_location_id','dropoff_latitude','dropoff_longitude']]

# %%
dropoff_location_dim
# Out:
#        dropoff_location_id  dropoff_latitude  dropoff_longitude
# 0                        0         40.746128         -74.004265
# 1                        1         40.733166         -74.005943
# 2                        2         40.675770         -73.974541
# 3                        3         40.757767         -73.969650
# 4                        4         40.695053         -74.177170
# ...                    ...               ...                ...
# 19628                19628         40.730461         -74.008774
# 19629                19629         40.757580         -73.967613
# 19630                19630         40.785141         -73.955742
# 19631                19631         40.740543         -73.989326
# 19632                19632         40.788300         -73.953293
#
# [19633 rows x 3 columns]

# %%
payment_type_dim = uber[['payment_type']].drop_duplicates().reset_index(drop=True)
payment_type_dim['payment_type_id'] = payment_type_dim.index
payment_type_dim = payment_type_dim[['payment_type_id','payment_type']]

# %%
payment_type_dim
# Out:
#    payment_type_id  payment_type
# 0                0           1.0
# 1                1           2.0
# 2                2           3.0
# 3                3           4.0
# 4                4           NaN

# %%
payment_type_name = {
    1 : "Credit card",
    2 : "Cash",
    3 : "No charge",
    4 : "Dispute",
    5 : "Unknown",
    6 : "Voided trip"
}

# %%
payment_type_dim['payment_type_name'] = payment_type_dim['payment_type'].map(payment_type_name)
payment_type_dim = payment_type_dim[['payment_type_id','payment_type', 'payment_type_name']]

# %%
payment_type_dim
# Out:
#    payment_type_id  payment_type payment_type_name
# 0                0           1.0       Credit card
# 1                1           2.0              Cash
# 2                2           3.0         No charge
# 3                3           4.0           Dispute
# 4                4           NaN               NaN

# %%
from datetime import date
fact_table = uber.merge(datetime_dim, on=['tpep_pickup_datetime','tpep_dropoff_datetime']) \
             .merge(pasanger_count_dim, on='passenger_count') \
             .merge(trip_distance_dim, on='trip_distance') \
             .merge(rate_code_dim, on='RatecodeID') \
             .merge(pickup_location_dim, on=['pickup_longitude','pickup_latitude']) \
             .merge(dropoff_location_dim, on=['dropoff_longitude','dropoff_latitude']) \
             .merge(payment_type_dim, on='payment_type') \
             [['VendorID', 'datetime_id', 'passenger_count_id',
               'trip_distance_id', 'rate_code_id', 'store_and_fwd_flag', 'pickup_location_id',
               'dropoff_location_id', 'payment_type_id', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
               'tolls_amount', 'improvement_surcharge', 'total_amount']]

# %%
fact_table
# Out:
#        VendorID  datetime_id  passenger_count_id  trip_distance_id  \
# 0             1            0                   0                 0
# 1             1            1                   0                 1
# 2             2            2                   1                 2
# 3             2            3                   2                 3
# 4             2            3                   3                 4
# ...         ...          ...                 ...               ...
# 19853         2        19818                   0               501
# 19854         2        19819                   3               186
# 19855         2        19820                   3               220
# 19856         2        19821                   0               347
# 19857         2        19822                   1               308
#
#        rate_code_id store_and_fwd_flag  pickup_location_id  \
# 0                 0                  N                   0
# 1                 0                  N                   1
# 2                 0                  N                   2
# 3                 0                  N                   3
# 4                 1                  N                   4
# ...             ...                ...                 ...
# 19853             0                  N               19589
# 19854             0                  N               19590
# 19855             0                  N               19591
# 19856             0                  N               19592
# 19857             0                  N               19593
#
#        dropoff_location_id  payment_type_id  fare_amount  extra  mta_tax  \
# 0                        0                0          9.0    0.5      0.5
# 1                        1                0         11.0    0.5      0.5
# 2                        2                0         54.5    0.5      0.5
# 3                        3                0         31.5    0.0      0.5
# 4                        4                0         98.0    0.0      0.0
# ...                    ...              ...          ...    ...      ...
# 19853                19628                0         11.0    0.0      0.5
# 19854                19629                0          7.0    0.0      0.5
# 19855                19630                0          6.5    0.0      0.5
# 19856                19631                0         11.5    0.0      0.5
# 19857                19632                4          NaN    NaN      NaN
#
#        tip_amount  tolls_amount  improvement_surcharge  total_amount
# 0            2.05          0.00                    0.3         12.35
# 1            3.05          0.00                    0.3         15.35
# 2            8.00          0.00                    0.3         63.80
# 3            3.78          5.54                    0.3         41.62
# 4            0.00         15.50                    0.3        113.80
# ...           ...           ...                    ...           ...
# 19853        2.36          0.00                    0.3         14.16
# 19854        1.20          0.00                    0.3          9.00
# 19855        1.46          0.00                    0.3          8.76
# 19856        1.00          0.00                    0.3         13.30
# 19857         NaN           NaN                    NaN           NaN
#
# [19858 rows x 16 columns]
